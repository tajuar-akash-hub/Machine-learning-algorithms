# %% [markdown]
# <a href="https://colab.research.google.com/github/tajuar-akash-hub/Machine-learning-algorithms/blob/main/Confusion_Matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1: Import the necessary libraries

# %%
#import libraries

import numpy as np
from sklearn.metrics import confusion_matrix,classification_report   #confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Step 2: Create the NumPy array for actual and predicted labels

# %%
actual = np.array( ['Dog','Dog','Dog','Not Dog','Dog','Not Dog','Dog','Dog','Not Dog','Not Dog'])
predicted = np.array( ['Dog','Not Dog','Dog','Not Dog','Dog','Dog','Dog','Dog','Not Dog','Not Dog'])

#each has 10 values

# %% [markdown]
# Step 3: Compute the confusion matrix

# %%
cm = confusion_matrix(actual,predicted)

# %% [markdown]
# Step 4: Plot the confusion matrix with the help of the seaborn heatmap

# %%
sns.heatmap(cm, annot=True, fmt='g', xticklabels=['Dog','Not Dog'], yticklabels=['Dog','Not Dog'])
plt.ylabel('Actual', fontsize=13)
plt.title('Confusion Matrix', fontsize=17, pad=20)
plt.gca().xaxis.set_label_position('top')
plt.xlabel('Prediction', fontsize=13)
plt.gca().xaxis.tick_top()
plt.gca().figure.subplots_adjust(bottom=0.2)
plt.gca().figure.text(0.5, 0.05, 'Prediction', ha='center', fontsize=13)
plt.show()

# %% [markdown]
# Step 5: Classifications Report based on Confusion Metrics

# %%
Step 5: Classifications Report based on Confusion Metrics
